# %% [markdown]
# ## Summary Stats for clustered vital 1k + links dataset
#
# **Author:** Jim Maddock
#
# **Last Updated:** 6-8-20
#
# **Description:** Some basic summary stats for clustered dataset produced by edcast, including distribution of cluster sizes and weights (closeness of article to centroid of cluster)

# %%
import json
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib

matplotlib.style.use('ggplot')

# %% [markdown]
# ### Notebook Setup
# Import data from json file and create pandas dataframe in order to run basic summary stats.  Dataframe creation takes a long time to run.

# %%
FILEPATH = '/Users/klogg/research_data/wmf_knowledge_graph/wiki_5-28-20/wiki_65_clusters_6-8-20.json'

with open(FILEPATH) as json_file:
    cluster_65 = json.load(json_file)

# %%
df = pd.DataFrame()

for i, cluster in enumerate(cluster_65):
    chunk = []
    for article in cluster_65[cluster]['items']:
        row = {
            'label':cluster_65[cluster]['label'],
            'cluster':cluster_65[cluster]['cluster'],
            'w':article['w'],
            'title':article['title']
        }
        chunk.append(row)
    df = df.append(pd.DataFrame(chunk))
    print('finished cluster: {0}'.format(i))
# Out:
# finished cluster: 0
# finished cluster: 1
# finished cluster: 2
# finished cluster: 3
# finished cluster: 4
# finished cluster: 5
# finished cluster: 6
# finished cluster: 7
# finished cluster: 8
# finished cluster: 9
# finished cluster: 10
# finished cluster: 11
# finished cluster: 12
# finished cluster: 13
# finished cluster: 14
# finished cluster: 15
# finished cluster: 16
# finished cluster: 17
# finished cluster: 18
# finished cluster: 19
# finished cluster: 20
# finished cluster: 21
# finished cluster: 22
# finished cluster: 23
# finished cluster: 24
# finished cluster: 25
# finished cluster: 26
# finished cluster: 27
# finished cluster: 28
# finished cluster: 29
# finished cluster: 30
# finished cluster: 31
# finished cluster: 32
# finished cluster: 33
# finished cluster: 34
# finished cluster: 35
# finished cluster: 36
# finished cluster: 37
# finished cluster: 38
# finished cluster: 39
# finished cluster: 40
# finished cluster: 41
# finished cluster: 42
# finished cluster: 43
# finished cluster: 44
# finished cluster: 45
# finished cluster: 46
# finished cluster: 47
# finished cluster: 48
# finished cluster: 49
# finished cluster: 50
# finished cluster: 51
# finished cluster: 52
# finished cluster: 53
# finished cluster: 54
# finished cluster: 55
# finished cluster: 56
# finished cluster: 57
# finished cluster: 58
# finished cluster: 59
# finished cluster: 60
# finished cluster: 61
# finished cluster: 62
# finished cluster: 63
# finished cluster: 64

# %% [markdown]
# ### Summary Stats
#
# * number of pages and clusters
# * distributions of pages per cluster: looks relatively normal, skewed to fewer pages per cluster
# * page weights
#     * relatively normally distributed and tightly clustered: median ~0.36, std ~0.12
#     * mean, quartiles, min, max, std for weights per cluster: median ~0.36, std ~0.12

# %%
print('number of pages: {0}'.format(len(df)))
print('number of clusters: {0}'.format(len(df['cluster'].unique())))
# Out:
# number of pages: 62043
# number of clusters: 65

# %% [markdown]
# ### Articles per cluster stats
# Distributions of pages per cluster: looks relatively normal, skewed to fewer pages per cluster.  No Cluster smaller than 230 articles.

# %%
articles_per_cluster = df.groupby('cluster').size()
articles_per_cluster.describe()
# Out:
# count      65.000000
# mean      954.507692
# std       401.985196
# min       230.000000
# 25%       729.000000
# 50%       918.000000
# 75%      1149.000000
# max      2295.000000
# dtype: float64

# %%
articles_per_cluster.hist(bins=10,figsize=(12,12))

# %% [markdown]
# ### Weights per cluster stats
# * relatively normally distributed and tightly clustered: median ~0.36, std ~0.12
# * mean, quartiles, min, max, std for weights per cluster: median ~0.36, std ~0.12

# %%
df['w'].describe()
# Out:
# count    62043.000000
# mean         0.377517
# std          0.124318
# min          0.050405
# 25%          0.286106
# 50%          0.363927
# 75%          0.454901
# max          0.873621
# Name: w, dtype: float64

# %%
df['w'].hist(bins=100,figsize=(12,12))

# %%
weights_per_cluster = df.groupby('label')['w'].describe().sort_values('50%')

# %%
weights_per_cluster.describe()
# Out:
#              count       mean        std        min        25%        50%  \
# count    65.000000  65.000000  65.000000  65.000000  65.000000  65.000000
# mean    954.507692   0.377223   0.121441   0.094793   0.285355   0.368688
# std     401.985196   0.036930   0.023537   0.020358   0.027287   0.040570
# min     230.000000   0.321563   0.080867   0.050405   0.227182   0.291110
# 25%     729.000000   0.346849   0.103049   0.081981   0.267290   0.339078
# 50%     918.000000   0.373681   0.118944   0.095351   0.280694   0.363597
# 75%    1149.000000   0.396682   0.137319   0.109039   0.301391   0.390817
# max    2295.000000   0.472797   0.191477   0.140962   0.371681   0.478205
#
#              75%        max
# count  65.000000  65.000000
# mean    0.461825   0.747200
# std     0.057798   0.061897
# min     0.378590   0.597441
# 25%     0.417115   0.699430
# 50%     0.448921   0.751709
# 75%     0.497979   0.794647
# max     0.616866   0.873621

# %% [markdown]
# ### Overview of cluster names, weights, size

# %%
df.groupby('label')['w'].describe().sort_values('50%')
# Out:
#                                              count      mean       std  \
# label
# desert_oblast_comedy_earthquake              338.0  0.335135  0.143578
# christmas_family_list_kinship                468.0  0.326797  0.118944
# river_mountain_peninsula_north              1199.0  0.321563  0.092622
# greek_ancient_roman_list                     778.0  0.329336  0.106640
# paper_glass_color_print                      853.0  0.324098  0.089620
# company_new_medium_oil                      1063.0  0.329345  0.086286
# day_year_calendar_child                      749.0  0.338616  0.114535
# acid_carbon_chemistry_reaction               955.0  0.329610  0.095065
# english_word_language_grammar               1095.0  0.337146  0.096431
# drug_management_theatre_policy               552.0  0.346849  0.121651
# poetry_literature_animal_poet                629.0  0.337694  0.103049
# cycle_bicycle_wheel_drive                    230.0  0.344542  0.126741
# group_element_ethnic_land                    743.0  0.346164  0.113863
# russia_russian_sea_soviet                    473.0  0.345828  0.123330
# book_comic_fiction_publish                   939.0  0.346568  0.108512
# stone_temple_architecture_circle             918.0  0.351164  0.107307
# physic_quantum_theory_particle               801.0  0.344171  0.107091
# plant_forest_species_tree                   1630.0  0.344756  0.088975
# genetic_evolution_tourism_population         772.0  0.353718  0.110521
# syndrome_heart_artery_disease                729.0  0.347876  0.108830
# time_comet_clock_great                       503.0  0.365803  0.145002
# empire_dynasty_roman_ii                     1252.0  0.349780  0.099005
# computer_image_photography_weapon           2295.0  0.347116  0.084140
# dive_air_engine_gas                         1067.0  0.350389  0.098335
# radio_television_telecommunication_network   606.0  0.360730  0.112583
# john_william_work_literature                1837.0  0.346982  0.080867
# water_lake_environmental_soil               1068.0  0.367767  0.124754
# science_engineer_scientific_journal          654.0  0.368933  0.131663
# disorder_emotional_syndrome_sleep           1127.0  0.359192  0.098960
# cuisine_food_list_milk                      1062.0  0.374953  0.132605
# press_philosophy_university_john            1322.0  0.358426  0.092185
# chinese_buddhism_china_buddhist              850.0  0.371225  0.113791
# game_summer_sport_olympics                   593.0  0.385295  0.137246
# religion_people_culture_freedom             1321.0  0.370317  0.095753
# university_school_education_college         1030.0  0.401967  0.146211
# economy_economic_market_economics           1301.0  0.377885  0.110348
# song_contest_eurovision_athletic             473.0  0.387800  0.143150
# religion_god_mythology_jewish               1151.0  0.381273  0.114879
# theory_social_society_human                 1645.0  0.373681  0.100174
# space_list_solar_moon                        811.0  0.374156  0.116395
# health_disease_medicine_medical             1173.0  0.374491  0.101382
# church_jesus_pope_john                      1149.0  0.383540  0.106804
# energy_power_system_nuclear                 1063.0  0.387235  0.120245
# war_military_force_world                    1019.0  0.395811  0.118294
# state_unite_union_liberalism                2199.0  0.386415  0.098829
# cell_protein_system_receptor                 932.0  0.396682  0.132708
# star_variable_stellar_supernova              465.0  0.406041  0.164445
# de_list_jean_la                              821.0  0.393684  0.120065
# law_right_legal_court                        838.0  0.393954  0.127314
# list_country_poet_egypt                      854.0  0.392968  0.147705
# island_sea_gulf_list                         828.0  0.410643  0.153747
# french_france_battle_war                     582.0  0.402875  0.131561
# city_province_list_prefecture               1550.0  0.410858  0.119058
# music_dance_folk_pop                        1245.0  0.436629  0.160881
# museum_national_art_history                  365.0  0.437481  0.191477
# dialect_german_language_min                  388.0  0.396493  0.139059
# equation_garden_law_force                    999.0  0.417361  0.137268
# woman_feminism_sexual_feminist               917.0  0.442188  0.171548
# script_braille_alphabet_write                682.0  0.411820  0.126387
# art_paint_sculpture_photography             1049.0  0.435764  0.137319
# rock_jazz_metal_music                       1241.0  0.440704  0.145070
# numb_function_theory_space                   953.0  0.439702  0.140633
# al_ibn_islam_islamic                         768.0  0.446893  0.151302
# film_animation_cinema_list                   880.0  0.451832  0.163152
# language_english_linguistic_consonant       1201.0  0.472797  0.145753
#
#                                                  min       25%       50%  \
# label
# desert_oblast_comedy_earthquake             0.114629  0.227182  0.291110
# christmas_family_list_kinship               0.087296  0.233893  0.306855
# river_mountain_peninsula_north              0.078761  0.256023  0.312635
# greek_ancient_roman_list                    0.090396  0.247311  0.316695
# paper_glass_color_print                     0.081981  0.255496  0.321006
# company_new_medium_oil                      0.110337  0.265994  0.321912
# day_year_calendar_child                     0.076554  0.254353  0.322265
# acid_carbon_chemistry_reaction              0.074058  0.262892  0.325647
# english_word_language_grammar               0.120727  0.266220  0.327570
# drug_management_theatre_policy              0.091247  0.255264  0.328885
# poetry_literature_animal_poet               0.066734  0.262944  0.330110
# cycle_bicycle_wheel_drive                   0.083559  0.245962  0.330741
# group_element_ethnic_land                   0.114421  0.263422  0.332132
# russia_russian_sea_soviet                   0.099304  0.250759  0.336821
# book_comic_fiction_publish                  0.086569  0.268841  0.336994
# stone_temple_architecture_circle            0.093125  0.271572  0.337580
# physic_quantum_theory_particle              0.094769  0.267290  0.339078
# plant_forest_species_tree                   0.114389  0.280694  0.339079
# genetic_evolution_tourism_population        0.092347  0.271489  0.339890
# syndrome_heart_artery_disease               0.131041  0.267579  0.341854
# time_comet_clock_great                      0.072356  0.249149  0.342939
# empire_dynasty_roman_ii                     0.079769  0.278086  0.343823
# computer_image_photography_weapon           0.118474  0.286726  0.343938
# dive_air_engine_gas                         0.096888  0.275603  0.346978
# radio_television_telecommunication_network  0.082238  0.276387  0.347627
# john_william_work_literature                0.104544  0.292484  0.348201
# water_lake_environmental_soil               0.122268  0.275320  0.350474
# science_engineer_scientific_journal         0.107998  0.266857  0.352265
# disorder_emotional_syndrome_sleep           0.095467  0.282126  0.356507
# cuisine_food_list_milk                      0.068789  0.269640  0.358297
# press_philosophy_university_john            0.109039  0.291981  0.358721
# chinese_buddhism_china_buddhist             0.084826  0.286220  0.362063
# game_summer_sport_olympics                  0.140962  0.272605  0.363597
# religion_people_culture_freedom             0.095683  0.301391  0.366915
# university_school_education_college         0.124262  0.296611  0.367719
# economy_economic_market_economics           0.129552  0.296277  0.368001
# song_contest_eurovision_athletic            0.101954  0.273997  0.368566
# religion_god_mythology_jewish               0.090295  0.297488  0.369276
# theory_social_society_human                 0.076243  0.304762  0.369867
# space_list_solar_moon                       0.050405  0.291961  0.371605
# health_disease_medicine_medical             0.097485  0.299749  0.373704
# church_jesus_pope_john                      0.117013  0.310513  0.375194
# energy_power_system_nuclear                 0.112691  0.299696  0.377520
# war_military_force_world                    0.119692  0.308410  0.385076
# state_unite_union_liberalism                0.099116  0.317091  0.386801
# cell_protein_system_receptor                0.052400  0.297514  0.387324
# star_variable_stellar_supernova             0.083366  0.267826  0.388309
# de_list_jean_la                             0.085984  0.307966  0.388770
# law_right_legal_court                       0.113917  0.302504  0.390817
# list_country_poet_egypt                     0.087286  0.274675  0.391985
# island_sea_gulf_list                        0.060906  0.292201  0.394280
# french_france_battle_war                    0.078531  0.301156  0.400185
# city_province_list_prefecture               0.106932  0.323097  0.410506
# music_dance_folk_pop                        0.055325  0.306869  0.412045
# museum_national_art_history                 0.094684  0.273651  0.416674
# dialect_german_language_min                 0.072961  0.270609  0.418651
# equation_garden_law_force                   0.095351  0.305677  0.422703
# woman_feminism_sexual_feminist              0.105763  0.298435  0.423279
# script_braille_alphabet_write               0.108273  0.318279  0.423689
# art_paint_sculpture_photography             0.122768  0.334707  0.430786
# rock_jazz_metal_music                       0.106760  0.331662  0.439789
# numb_function_theory_space                  0.051514  0.336518  0.444105
# al_ibn_islam_islamic                        0.101106  0.332975  0.451466
# film_animation_cinema_list                  0.095965  0.323763  0.456612
# language_english_linguistic_consonant       0.081507  0.371681  0.478205
#
#                                                  75%       max
# label
# desert_oblast_comedy_earthquake             0.430023  0.752576
# christmas_family_list_kinship               0.398202  0.727331
# river_mountain_peninsula_north              0.378590  0.655415
# greek_ancient_roman_list                    0.401373  0.702117
# paper_glass_color_print                     0.388750  0.597441
# company_new_medium_oil                      0.383017  0.630123
# day_year_calendar_child                     0.398338  0.737577
# acid_carbon_chemistry_reaction              0.396868  0.646098
# english_word_language_grammar               0.395630  0.694643
# drug_management_theatre_policy              0.417115  0.759093
# poetry_literature_animal_poet               0.406736  0.697954
# cycle_bicycle_wheel_drive                   0.424813  0.688803
# group_element_ethnic_land                   0.413881  0.727763
# russia_russian_sea_soviet                   0.426847  0.791487
# book_comic_fiction_publish                  0.419177  0.725994
# stone_temple_architecture_circle            0.423179  0.702188
# physic_quantum_theory_particle              0.414278  0.753179
# plant_forest_species_tree                   0.402687  0.697872
# genetic_evolution_tourism_population        0.422064  0.751709
# syndrome_heart_artery_disease               0.417652  0.695708
# time_comet_clock_great                      0.467074  0.764337
# empire_dynasty_roman_ii                     0.414738  0.698870
# computer_image_photography_weapon           0.400909  0.619856
# dive_air_engine_gas                         0.416394  0.635646
# radio_television_telecommunication_network  0.443608  0.699430
# john_william_work_literature                0.398547  0.654846
# water_lake_environmental_soil               0.437096  0.829320
# science_engineer_scientific_journal         0.451426  0.854895
# disorder_emotional_syndrome_sleep           0.430107  0.682751
# cuisine_food_list_milk                      0.459837  0.797846
# press_philosophy_university_john            0.425756  0.646712
# chinese_buddhism_china_buddhist             0.441837  0.804071
# game_summer_sport_olympics                  0.486554  0.755174
# religion_people_culture_freedom             0.440572  0.693853
# university_school_education_college         0.484977  0.808828
# economy_economic_market_economics           0.456404  0.753399
# song_contest_eurovision_athletic            0.509630  0.716662
# religion_god_mythology_jewish               0.453967  0.751444
# theory_social_society_human                 0.440184  0.734888
# space_list_solar_moon                       0.448921  0.813675
# health_disease_medicine_medical             0.444249  0.751154
# church_jesus_pope_john                      0.455555  0.746323
# energy_power_system_nuclear                 0.472802  0.785482
# war_military_force_world                    0.469353  0.805313
# state_unite_union_liberalism                0.452783  0.738487
# cell_protein_system_receptor                0.491714  0.780304
# star_variable_stellar_supernova             0.536215  0.777964
# de_list_jean_la                             0.476793  0.748568
# law_right_legal_court                       0.479353  0.794647
# list_country_poet_egypt                     0.502568  0.827020
# island_sea_gulf_list                        0.519370  0.799362
# french_france_battle_war                    0.497837  0.805612
# city_province_list_prefecture               0.497979  0.811337
# music_dance_folk_pop                        0.563481  0.861528
# museum_national_art_history                 0.616866  0.805598
# dialect_german_language_min                 0.499791  0.736680
# equation_garden_law_force                   0.526436  0.752811
# woman_feminism_sexual_feminist              0.583266  0.839474
# script_braille_alphabet_write               0.504255  0.730071
# art_paint_sculpture_photography             0.541212  0.794635
# rock_jazz_metal_music                       0.549233  0.771109
# numb_function_theory_space                  0.544374  0.794108
# al_ibn_islam_islamic                        0.566605  0.790545
# film_animation_cinema_list                  0.579126  0.794683
# language_english_linguistic_consonant       0.579636  0.873621
