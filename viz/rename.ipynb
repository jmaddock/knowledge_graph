# %%
import json

# %%
FILEPATH = '/Users/klogg/research_data/wmf_knowledge_graph/wiki_1300_72k_7-14-20/rename_hierarchical_nodes_7-4-20.json'

with open(FILEPATH) as json_file:
    name_map = json.load(json_file)
    
name_map
# Out:
# {'5436883832525112441': {'old': 'disease death syndrome cancer',
#   'new': 'disease death syndrome cancer'},
#  '5436883832949260940': {'old': 'list launch space system',
#   'new': 'launch space rocket satellite'},
#  '5436883833358536259': {'old': 'group newton robot hall',
#   'new': 'newton robot hall fame'},
#  '5436883833739252953': {'old': 'festival summit list composer',
#   'new': 'festival summit composer brics'},
#  '5436883834146226524': {'old': 'drug pneumonia dependence withdrawal',
#   'new': 'drug pneumonia dependence withdrawal'},
#  '5436883834565028839': {'old': 'syndrome sleep disorder disease',
#   'new': 'syndrome sleep disorder disease'},
#  '5436883835045072314': {'old': 'list country poet egypt',
#   'new': 'poet egypt film city'},
#  '5436883835530423036': {'old': 'animal vein vena heart',
#   'new': 'animal vein vena heart'},
#  '5436883842436224816': {'old': 'climate forest water river',
#   'new': 'climate forest water river'},
# ...

# %%
FILEPATH = '/Users/klogg/research_data/wmf_knowledge_graph/wiki_1300_72k_7-14-20/wc_rename_8_arity_8-13-20.json'

with open(FILEPATH) as json_file:
    name_map = json.load(json_file)
    
name_map
# Out:
# {'5436883826084107827': {'old': 'list disease country syndrome',
#   'new': 'disease treatment patient blood'},
#  '5436883832525112441': {'old': 'disease death syndrome cancer',
#   'new': 'risk rate symptom reduce'},
#  '5436883832949260940': {'old': 'list launch space system',
#   'new': 'stage upanishads yoga team'},
#  '5436883833358536259': {'old': 'group newton robot hall',
#   'new': 'science structure physical final'},
#  '5436883833739252953': {'old': 'festival summit list composer',
#   'new': 'international city opus perform'},
#  '5436883834146226524': {'old': 'drug pneumonia dependence withdrawal',
#   'new': 'risk medical treat test'},
#  '5436883834565028839': {'old': 'syndrome sleep disorder disease',
#   'new': 'condition syndrome symptom brain'},
#  '5436883835045072314': {'old': 'list country poet egypt',
#   'new': 'international south region government'},
#  '5436883835530423036': {'old': 'animal vein vena heart',
#   'new': 'human animal right species'},
# ...

# %%
name_map[5436883853621887368]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-a4301f990302> in <module>
# ----> 1 name_map[5436883853621887368]
#
# KeyError: 5436883853621887368

# %%
for x in name_map:
    if name_map[x]['old'] == 'reactor nuclear radiation power':
        print(name_map[x])
        break

# %%
name_map = {5436883832525112441: {'old': 'disease death syndrome cancer',
  'new': 'disease death syndrome cancer'},
 5436883832949260940: {'old': 'list launch space system',
  'new': 'launch space rocket satellite'},
 5436883833358536259: {'old': 'group newton robot hall',
  'new': 'newton robot hall fame'},
 5436883833739252953: {'old': 'festival summit list composer',
  'new': 'festival summit composer brics'},
 5436883834146226524: {'old': 'drug pneumonia dependence withdrawal',
  'new': 'drug pneumonia dependence withdrawal'},
 5436883834565028839: {'old': 'syndrome sleep disorder disease',
  'new': 'syndrome sleep disorder disease'},
 5436883835045072314: {'old': 'list country poet egypt',
  'new': 'poet egypt film city'},
 5436883835530423036: {'old': 'animal vein vena heart',
  'new': 'animal vein vena heart'},
 5436883842436224816: {'old': 'climate forest water river',
  'new': 'climate forest water river'},
 5436883842908481262: {'old': 'human mongoose evolution seal',
  'new': 'human mongoose evolution seal'},
 5436883843400500396: {'old': 'cell garden system plant',
  'new': 'cell garden plant genetic'},
 5436883845011592072: {'old': 'acid carbon chemistry reaction',
  'new': 'acid carbon chemistry reaction'},
 5436883845438446980: {'old': 'pen package bag machine',
  'new': 'pen package bag machine'},
 5436883845899281347: {'old': 'energy renewable power milk',
  'new': 'energy renewable power milk'},
 5436883846549055738: {'old': 'star earth list orbit',
  'new': 'star earth orbit moon'},
 5436883853621887368: {'old': 'reactor nuclear radiation power',
  'new': 'reactor nuclear radiation power'},
 5436883854934848368: {'old': 'color list vision green',
  'new': 'color vision green scheme'},
 5436883855327650118: {'old': 'power wind solar energy',
  'new': 'power wind solar energy'},
 5436883855697488312: {'old': 'engine space air heat',
  'new': 'engine space air heat'},
 5436883856216813268: {'old': 'fish transport power trawler',
  'new': 'fish transport power trawler'},
 5436883856563795342: {'old': 'dive battery laser light',
  'new': 'dive battery laser light'},
 5436883857021138120: {'old': 'test tower house steel',
  'new': 'test tower house steel'},
 5436883857434876461: {'old': 'space force cloud ice',
  'new': 'space force cloud ice'},
 5436883859206597781: {'old': 'literature mathematics spanish asian',
  'new': 'literature mathematics spanish asian'},
 5436883859625710496: {'old': 'university school john list',
  'new': 'school john library dictionary'},
 5436883860074917992: {'old': 'science journal society american',
  'new': 'science journal society american'},
 5436883861529745941: {'old': 'giovanni data pisano list',
  'new': 'giovanni data pisano hans'},
 5436883862036270663: {'old': 'international list association artist',
  'new': 'international association artist space'},
 5436883862458313793: {'old': 'university press philosophy study',
  'new': 'press philosophy anthropology john'},
 5436883863520204290: {'old': 'van list jan society',
  'new': 'jan society landauer den'},
 5436883863903836597: {'old': 'jean francois louis pierre',
  'new': 'jean francois louis pierre'},
 5436883865081715725: {'old': 'liberalism african party tourism',
  'new': 'liberalism african party tourism'},
 5436883873260257226: {'old': 'woman religion freedom islam',
  'new': 'woman religion freedom islam'},
 5436883874677375038: {'old': 'state constitution republic unite',
  'new': 'constitution republic government party'},
 5436883875998132510: {'old': 'war history force military',
  'new': 'war force military warfare'},
 5436883876431187799: {'old': 'university state airport drug',
  'new': 'airport drug international california'},
 5436883876968168016: {'old': 'battle war french jean',
  'new': 'battle war french jean'},
 5436883877402152474: {'old': 'nuclear weapon destruction mass',
  'new': 'nuclear weapon destruction mass'},
 5436883877761078359: {'old': 'vehicle italian class submarine',
  'new': 'vehicle italian class submarine'},
 5436883878158084778: {'old': 'military relation india island',
  'new': 'military relation india island'},
 5436883878536375236: {'old': 'province governorate city district',
  'new': 'province governorate city district'},
 5436883878967289815: {'old': 'sea island desert list',
  'new': 'sea island desert river'},
 5436883879399046471: {'old': 'contest eurovision song game',
  'new': 'contest eurovision song game'},
 5436883880552548419: {'old': 'economy unite state nation',
  'new': 'economy nation international union'},
 5436883901494626874: {'old': 'people history dynasty empire',
  'new': 'dynasty empire kingdom cuisine'},
 5436883902237303592: {'old': 'santa mare rome lateran',
  'new': 'santa mare rome lateran'},
 5436883902600969405: {'old': 'ancient roman temple empire',
  'new': 'ancient roman temple empire'},
 5436883903365875442: {'old': 'banu muhammad battle invasion',
  'new': 'banu muhammad battle invasion'},
 5436883903747665733: {'old': 'oblast people russia demographics',
  'new': 'oblast russia demographics krai'},
 5436883904160579525: {'old': 'religion christianity christian list',
  'new': 'religion christianity christian religious'},
 5436883904707189916: {'old': 'prefecture culture island france',
  'new': 'prefecture culture island france'},
 5436883905522564623: {'old': 'church orthodox council christianity',
  'new': 'church orthodox council christianity'},
 5436883905931204002: {'old': 'king lugal list damu',
  'new': 'king lugal damu sumerian'},
 5436883907609547996: {'old': 'sexual sex nuclear lgbt',
  'new': 'sexual sex nuclear lgbt'},
 5436883908100826201: {'old': 'cultural occupational datum hazard',
  'new': 'cultural occupational datum hazard'},
 5436883914960061476: {'old': 'market bank economics tax',
  'new': 'market bank economics tax'},
 5436883915434815787: {'old': 'journal open science academic',
  'new': 'journal open science academic'},
 5436883915842449616: {'old': 'information standard international organization',
  'new': 'information standard international organization'},
 5436883916579748835: {'old': 'journalism telecommunication television national',
  'new': 'journalism telecommunication television science'},
 5436883917088024492: {'old': 'game time radio car',
  'new': 'game radio car video'},
 5436883917576347028: {'old': 'management health water system',
  'new': 'management health water service'},
 5436883918106340657: {'old': 'transport railway bus rail',
  'new': 'transport railway bus rail'},
 5436883918503010564: {'old': 'digital network internet computer',
  'new': 'digital network internet computer'},
 5436883918981286406: {'old': 'theory philosophy science social',
  'new': 'theory philosophy science social'},
 5436883919435427263: {'old': 'law right legal company',
  'new': 'law right legal company'},
 5436883919924134091: {'old': 'feminism social education woman',
  'new': 'feminism social education woman'},
 5436883921153412524: {'old': 'engineer bicycle robot theatre',
  'new': 'engineer bicycle robot theatre'},
 5436883921572408793: {'old': 'dive film animation game',
  'new': 'dive film animation game'},
 5436883928552494579: {'old': 'language dialect script german',
  'new': 'language dialect script german'},
 5436883929253819372: {'old': 'paper glass dress bridge',
  'new': 'paper glass dress bridge'},
 5436883929689321370: {'old': 'book system line codex',
  'new': 'book line codex carve'},
 5436883930388645463: {'old': 'language braille script alphabet',
  'new': 'language braille script alphabet'},
 5436883931495198703: {'old': 'instrument guitar bass musical',
  'new': 'instrument guitar bass musical'},
 5436883931960456480: {'old': 'calendar unit code list',
  'new': 'calendar unit code oil'},
 5436883933146117910: {'old': 'cuisine wine list pepper',
  'new': 'cuisine wine pepper food'},
 5436883933772028528: {'old': 'language dialect jupiter list',
  'new': 'language dialect jupiter min'},
 5436883940716459907: {'old': 'art museum national paint',
  'new': 'art museum paint sculpture'},
 5436883941200799213: {'old': 'literature poetry john list',
  'new': 'literature poetry john christmas'},
 5436883942575993047: {'old': 'music rock jazz pop',
  'new': 'music rock jazz pop'},
 5436883943655070335: {'old': 'pope church saint jesus',
  'new': 'pope church saint jesus'},
 5436883944310661803: {'old': 'dance folk ali tabrizi',
  'new': 'dance folk ali tabrizi'},
 5436883944766953350: {'old': 'film comic cinema comedy',
  'new': 'film comic cinema comedy'},
 5436883951829186758: {'old': 'mythology religion christian christianity',
  'new': 'mythology religion christian christianity'},
 5436883952624884843: {'old': 'list war world love',
  'new': 'war love equipment military'},
 5436883953045215352: {'old': 'sikhism guru sikh singh',
  'new': 'sikhism guru sikh singh'},
 5436883953487317784: {'old': 'philosophy god religion buddhism',
  'new': 'philosophy god religion buddhism'},
 5436883953939309648: {'old': 'dance hinduism history folk',
  'new': 'dance hinduism folk book'},
 5436883954362525123: {'old': 'jesus matthew act luke',
  'new': 'jesus matthew act luke'},
 5436883954986879072: {'old': 'ibn abu islam muhammad',
  'new': 'ibn abu islam muhammad'},
 5436883955614344283: {'old': 'buddhism religion buddhist folk',
  'new': 'buddhism religion buddhist folk'},
 5436883956059448478: {'old': 'music opus orchestra list',
  'new': 'music opus orchestra classical'},
 5436883962757156216: {'old': 'numb function theorem set',
  'new': 'function theorem theory integral'},
 5436883963684850325: {'old': 'schwarzschild metric ratio list',
  'new': 'schwarzschild metric ratio coordinate'},
 5436883964040833103: {'old': 'space geometry group polytope',
  'new': 'space geometry polytope coordinate'},
 5436883964481602018: {'old': 'rock dasht geology reza',
  'new': 'rock dasht geology reza'},
 5436883964879755539: {'old': 'list river s2004 artist',
  'new': 'river s2004 artist poet'},
 5436883965552684992: {'old': 'equation theory wave law',
  'new': 'equation theory wave law'},
 5436883966038578559: {'old': 'learning mathematics black hole',
  'new': 'learning mathematics black hole'},
 5436883966872155193: {'old': 'star variable list comet',
  'new': 'star variable comet main'}}

# %%
with open('/Users/klogg/research_data/wmf_knowledge_graph/wiki_1300_72k_7-14-20/rename_hierarchical_nodes_7-4-20.json', 'w') as outfile:
    json.dump(name_map, outfile)
